# %% [markdown]
# ***Logic Operators***

# %% [markdown]
# <style>
#     .jp-Notebook { background: white !important; color: black !important; }
#     pre, code { background: white !important; color: black !important; }
# </style>

# %%
#import libraries
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
#read the image
# reading image and converting to gray scale
img = Image.open("../images/rectangle.png").convert('L')
# display image
img
# Out:
# <PIL.Image.Image image mode=L size=457x309>

# %%
img = img.resize((300,300), Image.Resampling.LANCZOS)
# convert to numpy array 
numpy_image = np.array(img)

# %%
#read the image
# reading image and converting to gray scale
img2 = Image.open("../images/triangle.png").convert('L')
# display image
img2
# Out:
# <PIL.Image.Image image mode=L size=485x336>

# %%
img2 = img2.resize((300,300), Image.Resampling.LANCZOS)
# convert to numpy array 
numpy_image2 = np.array(img2)

# %%
# Logic AND
aa = numpy_image*numpy_image2
aa = Image.fromarray(aa)  
aa = aa.convert("L")
aa
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
# Logic OR
aa = numpy_image+numpy_image2
aa = Image.fromarray(aa)  
aa = aa.convert("L")
aa
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
#XOR
aa = np.logical_xor(numpy_image, numpy_image2)
aa = Image.fromarray(aa)  
aa = aa.convert("L")
aa
# Out:
# <PIL.Image.Image image mode=L size=300x300>
